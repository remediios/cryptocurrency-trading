# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

btc_data = pd.read_csv('btc.csv')
eth_data = pd.read_csv('eth.csv')
btc_data
# Out:
#         ID                 Date   Price (GBP)  Market Cap (GBP)  Total Volume  \
# 0      243  2013-12-27 00:00:00    453.087000      5.519257e+09  3.880170e+07
# 1      244  2013-12-28 00:00:00    443.243500      5.401144e+09  1.687134e+07
# 2      245  2013-12-29 00:00:00    451.859600      5.507909e+09  1.680521e+07
# 3      246  2013-12-30 00:00:00    457.693700      5.579252e+09  1.487517e+07
# 4      247  2013-12-31 00:00:00    457.389300      5.575541e+09  1.326663e+07
# ...    ...                  ...           ...               ...           ...
# 3394  3706  2023-06-22 00:00:00  23571.096637      4.573319e+11  1.860305e+10
# 3395  3707  2023-06-23 00:00:00  23483.066477      4.561086e+11  1.538576e+10
# 3396  3708  2023-06-24 00:00:00  24090.972707      4.675910e+11  1.780004e+10
# 3397  3709  2023-06-25 00:00:00  24019.061630      4.663461e+11  9.230869e+09
# 3398  3710  2023-06-25 17:08:59  24062.830201      4.671217e+11  7.952582e+09
#
# ...

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# Plot btc_data
ax1.plot(btc_data['Price (GBP)'])
ax1.set_title('Bitcoin Price (GBP)')
ax1.set_xlabel('Index')
ax1.set_ylabel('Price (GBP)')

# Plot eth_data
ax2.plot(eth_data['Price (GBP)'], color="orange")
ax2.set_title('Ethereum Price (GBP)')
ax2.set_xlabel('Index')
ax2.set_ylabel('Price (GBP)')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot btc_data histogram
ax1.hist(btc_data['Price (GBP)'], bins=5)
ax1.set_title('Bitcoin Price (GBP) - Histogram')
ax1.set_xlabel('Price (GBP)')
ax1.set_ylabel('Frequency')

# Plot eth_data histogram
ax2.hist(eth_data['Price (GBP)'], bins=5, color="orange")
ax2.set_title('Ethereum Price (GBP) - Histogram')
ax2.set_xlabel('Price (GBP)')
ax2.set_ylabel('Frequency')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Count the occurrences of each class in btc_data and eth_data
btc_class_counts = btc_data['Class'].value_counts()
eth_class_counts = eth_data['Class'].value_counts()

# Get the unique classes
classes = sorted(set(btc_data['Class']) | set(eth_data['Class']))

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot bar chart for btc_data
ax1.bar(classes, [btc_class_counts.get(cls, 0) for cls in classes])
ax1.set_title('Bitcoin Data')
ax1.set_xlabel('Class')
ax1.set_ylabel('Counts')

# Plot bar chart for eth_data
ax2.bar(classes, [eth_class_counts.get(cls, 0) for cls in classes], color="orange")
ax2.set_title('Ethereum Data')
ax2.set_xlabel('Class')
ax2.set_ylabel('Counts')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot horizontal box plot for btc_data
ax1.boxplot(btc_data['Price (GBP)'], vert=False)
ax1.set_title('Bitcoin Data')
ax1.set_xlabel('Price (GBP)')

# Plot horizontal box plot for eth_data
ax2.boxplot(eth_data['Price (GBP)'], vert=False)
ax2.set_title('Ethereum Data')
ax2.set_xlabel('Price (GBP)')

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Select columns with indexes 2, 3, 4, 5, and 6 from btc_data
btc_selected_columns = btc_data.iloc[:, [2, 3, 4, 5, 6]]

# Select columns with indexes 2, 3, 4, 5, and 6 from eth_data
eth_selected_columns = eth_data.iloc[:, [2, 3, 4, 5, 6]]

# Create the heatmap data for btc_data
btc_heatmap = btc_selected_columns.corr()

# Create the heatmap data for eth_data
eth_heatmap = eth_selected_columns.corr()

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Plot heatmap for btc_data
heatmap1 = ax1.pcolormesh(btc_heatmap, cmap='coolwarm')
ax1.set_title('Bitcoin Data')
ax1.set_xticks(np.arange(len(btc_heatmap.columns))+0.5)
ax1.set_yticks(np.arange(len(btc_heatmap.columns))+0.5)
ax1.set_xticklabels(btc_heatmap.columns, rotation=45)
ax1.set_yticklabels(btc_heatmap.columns)
plt.colorbar(heatmap1, ax=ax1, fraction=0.046, pad=0.04)

# Plot heatmap for eth_data
heatmap2 = ax2.pcolormesh(eth_heatmap, cmap='coolwarm')
ax2.set_title('Ethereum Data')
ax2.set_xticks(np.arange(len(eth_heatmap.columns))+0.5)
ax2.set_yticks(np.arange(len(eth_heatmap.columns))+0.5)
ax2.set_xticklabels(eth_heatmap.columns, rotation=45)
ax2.set_yticklabels(eth_heatmap.columns)
plt.colorbar(heatmap2, ax=ax2, fraction=0.046, pad=0.04)

# Adjust layout and display the plots
plt.tight_layout()
plt.show()

# %%
btc_heatmap
# Out:
#                   Price (GBP)  Market Cap (GBP)  Total Volume  % 24hr Change  \
# Price (GBP)          1.000000          0.999700      0.695581       0.007918
# Market Cap (GBP)     0.999700          1.000000      0.694630       0.006725
# Total Volume         0.695581          0.694630      1.000000       0.003786
# % 24hr Change        0.007918          0.006725      0.003786       1.000000
# % 7d Change          0.018899          0.015966      0.041315       0.386636
#
#                   % 7d Change
# Price (GBP)          0.018899
# Market Cap (GBP)     0.015966
# Total Volume         0.041315
# % 24hr Change        0.386636
# % 7d Change          1.000000

# %%
eth_heatmap
# Out:
#                   Price (GBP)  Market Cap (GBP)  Total Volume  % 24hr Change  \
# Price (GBP)          1.000000          0.999338      0.591162      -0.015248
# Market Cap (GBP)     0.999338          1.000000      0.589224      -0.016549
# Total Volume         0.591162          0.589224      1.000000      -0.012024
# % 24hr Change       -0.015248         -0.016549     -0.012024       1.000000
# % 7d Change         -0.043981         -0.046700     -0.016654       0.366803
#
#                   % 7d Change
# Price (GBP)         -0.043981
# Market Cap (GBP)    -0.046700
# Total Volume        -0.016654
# % 24hr Change        0.366803
# % 7d Change          1.000000

# %%
from scipy.stats import skew, kurtosis

# Calculate skewness and kurtosis for btc_data
btc_price_skewness = skew(btc_data["Price (GBP)"])
btc_price_kurtosis = kurtosis(btc_data["Price (GBP)"])

# Calculate skewness and kurtosis for eth_data
eth_price_skewness = skew(eth_data["Price (GBP)"])
eth_price_kurtosis = kurtosis(eth_data["Price (GBP)"])

print("Bitcoin Data:")
print("Skewness:", btc_price_skewness)
print("Kurtosis:", btc_price_kurtosis)
print()
print("Ethereum Data:")
print("Skewness:", eth_price_skewness)
print("Kurtosis:", eth_price_kurtosis)
# Out:
# Bitcoin Data:
# Skewness: 1.3660538145635774
# Kurtosis: 0.8727251983918611
#
# Ethereum Data:
# Skewness: 1.4031732353308903
# Kurtosis: 1.0857829079512067

# %%
import matplotlib.pyplot as plt

# Extract columns 5 and 6 from btc_data
btc_columns = btc_data.iloc[:, [5, 6]]

# Extract columns 5 and 6 from eth_data
eth_columns = eth_data.iloc[:, [5, 6]]

# Create subplots for the scatter plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Scatter plot for btc_data
ax1.scatter(btc_columns.iloc[:, 0], btc_columns.iloc[:, 1])
ax1.set_xlabel('% 24hr Change')
ax1.set_ylabel('% 7d Change')
ax1.set_title('Bitcoin Data')

# Scatter plot for eth_data
ax2.scatter(eth_columns.iloc[:, 0], eth_columns.iloc[:, 1], c="orange")
ax2.set_xlabel('% 24hr Change')
ax2.set_ylabel('% 7d Change')
ax2.set_title('Ethereum Data')

# Adjust layout and display the scatter plots
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract columns 5 and 6 from btc_data
btc_columns = btc_data.iloc[:, [2, 4]]

# Extract columns 5 and 6 from eth_data
eth_columns = eth_data.iloc[:, [2, 4]]

# Create subplots for the scatter plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Scatter plot for btc_data
ax1.scatter(btc_columns.iloc[:, 0], btc_columns.iloc[:, 1])
ax1.set_xlabel('Price')
ax1.set_ylabel('Total Volume')
ax1.set_title('Bitcoin Data')

# Scatter plot for eth_data
ax2.scatter(eth_columns.iloc[:, 0], eth_columns.iloc[:, 1], c="orange")
ax2.set_xlabel('Price')
ax2.set_ylabel('Total Volume')
ax2.set_title('Ethereum Data')

# Adjust layout and display the scatter plots
plt.tight_layout()
plt.show()
